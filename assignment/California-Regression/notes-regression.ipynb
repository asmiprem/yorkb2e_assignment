# %% [markdown]
# ### Regression
# * Predict output that is in a continuous domain
#
#
# ### Assignment
# * Apply the Regressor to scikit-learns "California Housing dataset" with your target being the median house value
# * Look into what statistics are available to you to analyze the performance of your model.
# * Using those statistics, attempt to hand-tune your model (don't spend too much time on this!)
# * After tuning your model, come up with an explanation for why the Model performed as it did
# * Be prepared to explain your regressor to the rest of the group

# %% [markdown]
# ### SGD
# * Stochastic Gradient Descent
# * What you are trying to do is fit a regression to the data
# * Take small batches of the data (stochastic part)
# * Predict and calculate loss and gradient of the loss function
# * Adjusts the coefficients until loss function gradient is minimized

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
import pandas as pd

# %%
data = fetch_california_housing()
X = data.data
y = data.target

# %%
df = pd.DataFrame(X, columns = data.feature_names)
df['target'] = y
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 16)

# %% [markdown]
# ### Loss Functions:
# * Squared Error: take the difference between the actual and predicted values and square
# * Huber: quadratic for small values and linear for large, decreases the influence of outliers
# * Epsilon-insensitive: sets all losses less than e = 0, penalizes larger errors

# %%
lossf = ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive']
learning_rates = ['constant', 'optimal', 'invscaling', 'adaptive']
stats = pd.DataFrame(columns = ["loss function", "learning rate", "MSE", "Absolute_Error_Percentage", "R2"])
for l in lossf: 
    for lr in learning_rates:
        model = SGDRegressor(loss = l, learning_rate= lr)
        model.fit(X_train, y_train)
        pred = model.predict(X_test)
        r2 = r2_score(y_pred = pred, y_true = y_test)
        mean_abs = mean_absolute_percentage_error(y_test, pred)
        mse = mean_squared_error(y_test, pred)
        stats.loc[len(stats.index)] = [l, lr, mse, mean_abs, r2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
stats.head(20)
# Out:
#                   loss function learning rate           MSE  \
# 0                 squared_error      constant  1.258596e+32
# 1                 squared_error       optimal  1.316212e+30
# 2                 squared_error    invscaling  6.120450e+29
# 3                 squared_error      adaptive  1.048396e+27
# 4                         huber      constant  6.579992e+05
# 5                         huber       optimal  1.436377e+04
# 6                         huber    invscaling  5.738458e+02
# 7                         huber      adaptive  8.200067e-01
# 8           epsilon_insensitive      constant  2.776035e+07
# 9           epsilon_insensitive       optimal  7.201817e+05
# 10          epsilon_insensitive    invscaling  7.593460e+03
# 11          epsilon_insensitive      adaptive  4.231216e+00
# 12  squared_epsilon_insensitive      constant  1.881648e+32
# 13  squared_epsilon_insensitive       optimal  1.190060e+32
# 14  squared_epsilon_insensitive    invscaling  1.464196e+30
# 15  squared_epsilon_insensitive      adaptive  8.494852e+26
#
#     Absolute_Error_Percentage            R2
# 0                5.861799e+15 -9.409286e+31
# 1                5.306295e+14 -9.840026e+29
# 2                3.709561e+14 -4.575661e+29
# 3                1.268396e+12 -7.837828e+26
# 4                3.931735e+02 -4.919205e+05
# 5                5.673049e+01 -1.073738e+04
# 6                1.215897e+01 -4.280083e+02
# 7                4.069983e-01  3.869614e-01
# 8                2.992874e+03 -2.075369e+07
# 9                3.989154e+02 -5.384082e+05
# 10               3.244239e+01 -5.675886e+03
# 11               7.326559e-01 -2.163266e+00
# 12               6.893875e+15 -1.406723e+32
# 13               5.347823e+15 -8.896911e+31
# 14               5.746944e+14 -1.094636e+30
# 15               1.116862e+12 -6.350768e+26

# %% [markdown]
# # GradientBoostingRegressor

# %%
model =  GradientBoostingRegressor()
model.fit(X_train, y_train)
pred = model.predict(X_test)
r2 = r2_score(y_pred = pred, y_true = y_test)
mean_abs = mean_absolute_percentage_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
print(r2)
print(mean_abs)
print(mse)
# Out:
# 0.791824831446877
# 0.21073877246276435
# 0.27845722314219257

# %% [markdown]
# # AdaBoostRegressor

# %%
model =  AdaBoostRegressor()
model.fit(X_train, y_train)
pred = model.predict(X_test)
r2 = r2_score(y_pred = pred, y_true = y_test)
mean_abs = mean_absolute_percentage_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
print(r2)
print(mean_abs)
print(mse)
# Out:
# 0.3891381433190342
# 0.5904294290245115
# 0.817095033558045

# %%
model = SVR(kernel='linear')
model.fit(X_train, y_train)
pred = model.predict(X_test)
r2 = r2_score(y_pred = pred, y_true = y_test)
mean_abs = mean_absolute_percentage_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
print(r2)
print(mean_abs)
print(mse)
