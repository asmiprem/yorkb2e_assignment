# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stormCSV.csv")


print(df.describe())
# Out:
#         magnitude
# count  227.000000
# mean    88.268722
# std      9.485575
# min     80.000000
# 25%     83.000000
# 50%     87.000000
# 75%     90.000000
# max    144.000000

# %%
print(df.head())
df.info()
# Out:
#   state event_type magnitude_type  magnitude
# 0    Ha  high wind             MG      144.0
# 1    Ca  high wind             MG      139.0
# 2    Ca  high wind             MG      136.0
# 3    Ut  high wind             MG      129.0
# 4    Ut  high wind             MG      113.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           227 non-null    object
#  1   event_type      227 non-null    object
#  2   magnitude_type  227 non-null    object
#  3   magnitude       227 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 7.2+ KB

# %%
ystate=[df[] for y in ]
occurrence={item:ystate.count(item) for item  in ystate}

# %%
df.plot(x="state",y="magnitude" ,figsize=(10,5))

plt.title("Temperature trends")
plt.xlabel("state")
plt.ylabel("magnitude")
plt.show()

# %%
df.hist("magnitude",bins=25, figsize=(10,5))
plt.text(125,50,'DataSet: Severe Weather 2022', fontsize = 10) 

plt.xlabel("Windspeed")
plt.ylabel("Frequency of Occurrence")
# Out:
# Text(0, 0.5, 'Frequency of Occurrence')
